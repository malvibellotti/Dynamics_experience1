# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
#import sys
#!{sys.executable} -m pip install pandas

# %% [markdown]
# # Visualizzazione dati

# %%
f = open("figure8.out", "r")
lines = f.readlines()
print(len(lines))

elements= []
for line in lines:
    elements = np.append(elements, [line.split()])
print (len(elements))

n_bodies = int(lines[0])
n_timelapses = int(len(lines) / (2+n_bodies))
print(n_timelapses)

'''
event = 0 
print(elements[ event:(event + 2 + (n_bodies*1) +(n_bodies*6)) ])
event = event + 2 +(n_bodies*1) + n_bodies*6
print(event)
print(elements[event :(event + 2 + (n_bodies*1) +(n_bodies*6)) ])
'''
# Out:
# 50
# 230
# 10
# '\nevent = 0 \nprint(elements[ event:(event + 2 + (n_bodies*1) +(n_bodies*6)) ])\nevent = event + 2 +(n_bodies*1) + n_bodies*6\nprint(event)\nprint(elements[event :(event + 2 + (n_bodies*1) +(n_bodies*6)) ])\n'

# %%
timelapse = [["n_bodies","time", "1", "x", "y", "z", "vx", "vy", "vz"]]

#print(timelapse)
   
event = 0


for i in range(n_timelapses):
    array = elements[event :(event + 2 + (n_bodies*1) +(n_bodies*6))]
    #print(array)
    timelapse.append(array)
    event = event + 2 + (n_bodies*1) + n_bodies*6

#print(timelapse)
#print (timelapse[0])
print (timelapse[1])
#print (timelapse[2])
# Out:
# ['3' '1.009683292521411' '1' '0.9897069007297181' '0.2235109578712773' '0'
#  '-0.4136156720190455' '0.4440307140425451' '0' '1' '-0.04171517829958487'
#  '0.03859082267230612' '0' '0.9356534105818086' '-0.8605658873713762' '0'
#  '1' '-0.9479917224301343' '-0.2621017805435834' '0' '-0.5220377385627627'
#  '0.4165351733288307' '0']

# %%
#qua raga ho salvato tutti i valori, sicuramente lo posso fare meglio con un ciclo, con tre corpi ancora è ok, di più no ahaha
time = timelapse[1][1]

x1 = timelapse[1][3] 
y1 = timelapse[1][4]
z1 = timelapse[1][5]
vx_1 = timelapse[1][6]
vy_1 = timelapse[1][7]
vz_1 = timelapse[1][8]

x2 = timelapse[1][10]
y2 = timelapse[1][11]
z2 = timelapse[1][12]
vx_2 = timelapse[1][13]
vy_2 = timelapse[1][14]
vz_2 = timelapse[1][15]

x3 = timelapse[1][16]
y3 = timelapse[1][17]
z3 = timelapse[1][18]
vx_3 = timelapse[1][19]
vy_3 = timelapse[1][20]
vz_3 = timelapse[1][21]

for i in range(n_timelapses-1):
    time = np.append(time, timelapse[i+2][1])
    
    x1 = np.append(x1, timelapse[i+2][3])
    y1 = np.append(y1, timelapse[i+2][4])
    z1 = np.append(z1,timelapse[i+2][5])
    vx_1 = np.append(vx_1,timelapse[i+2][6])
    vy_1 = np.append(vy_1,timelapse[i+2][7])
    vz_1 = np.append(vz_1,timelapse[i+2][8])
                       
    x2 = np.append(x2,timelapse[i+2][10])
    y2 = np.append(y2, timelapse[i+2][11])
    z2 = np.append(z2, timelapse[i+2][12])
    vx_2 = np.append(vx_2, timelapse[i+2][13])
    vy_2 = np.append(vy_2, timelapse[i+2][14])
    vz_2 = np.append(vz_2, timelapse[i+2][15])

    x3 = np.append(x3,timelapse[i+2][16])
    y3 = np.append(y3, timelapse[i+2][17])
    z3 = np.append(z3, timelapse[i+2][18])
    vx_3 = np.append(vx_3, timelapse[i+2][19])
    vy_3 = np.append(vy_3, timelapse[i+2][20])
    vz_3 = np.append(vz_3, timelapse[i+2][21])

print(x1, y1)
print(x1.size)
# Out:
# ['0.9897069007297181' '0.09432319302353478' '-0.8839891670686627'
#  '-1.044419774070486' '-0.2609376332069616' '0.7493147827417624'
#  '1.072624947464457' '0.4352826278427979' '-0.5821954606677395'
#  '-1.081032480785939'] ['0.2235109578712773' '0.08623646241095788' '-0.3041589003768859'
#  '0.1465453168593974' '0.2189713616297131' '-0.3501694690994556'
#  '0.07188201107877507' '0.3133260674114481' '-0.3526857147835861'
#  '-0.004140733582969548']
# 10

# %% [markdown]
# ## plotting the position

# %%
plt.figure(figsize=(10, 8))
#IF I WANT POINTS:

for i in range(len(x1)):
    plt.scatter(x1[i], y1[i])
for i in range(len(x2)):
    plt.scatter(x2[i], y2[i])
for i in range(len(x3)):
    plt.scatter(x3[i], y3[i])


#IF I WANT THE PLOT OF THE ORBITS
plt.plot(x1, y1, label='1', color = 'red')
plt.plot(x2, y2, label='2', color = 'green')
plt.plot(x3, y3, label='3', color = 'blue')

plt.title('three masses simulation...')
plt.xlabel('x')
plt.ylabel('y')
#plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
#graph = plt.scatter(x1[0], y1[0])

scat = ax.scatter(x1[0], y1[0], c="b", s=5, label="1")

def update(frame):
    x = t[:frame]
    y = z[:frame]
    # update the scatter plot:
    data = np.stack([x, y]).T
    scat.set_offsets(data)
    return graph

ani = animation.FuncAnimation(fig=fig, func=update, frames=40, interval=30)
plt.show()
# Out:
# /home/malvi/snap/jupyter/common/lib/python3.7/site-packages/matplotlib/animation.py:888: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you have outputted the Animation using `plt.show()` or `anim.save()`.
#   'Animation was deleted without rendering anything. This is '

# %%
fig, ax = plt.subplots()
t = np.linspace(0, 3, 40)
g = -9.81
v0 = 12
z = g * t**2 / 2 + v0 * t

v02 = 5
z2 = g * t**2 / 2 + v02 * t

scat = ax.scatter(t[0], z[0], c="b", s=5, label=f'v0 = {v0} m/s')
line2 = ax.plot(t[0], z2[0], label=f'v0 = {v02} m/s')[0]
ax.set(xlim=[0, 3], ylim=[-4, 10], xlabel='Time [s]', ylabel='Z [m]')
ax.legend()


def update(frame):
    # for each frame, update the data stored on each artist.
    x = x1[:frame]
    y = y1[:frame]
    # update the scatter plot:
    data = np.stack([x, y]).T
    scat.set_offsets(data)
    # update the line plot:
    line2.set_xdata(x1[:frame])
    line2.set_ydata(z2[:frame])
    return (scat, line2)


ani = animation.FuncAnimation(fig=fig, func=update, frames=40, interval=30)
plt.show()

# %%
#let's try and do x vs time and y vs time
plt.figure(figsize=(10, 8))
#IF I WANT POINTS:

for i in range(len(x1)):
    plt.scatter(time[i], x1[i], color = "orange")
    plt.scatter(time[i], y1[i], color = "red")
for i in range(len(x2)):
    plt.scatter(time[i], x2[i], color = "lightgreen")
    plt.scatter(time[i], y2[i], color = "darkgreen")
for i in range(len(x3)):
    plt.scatter(time[i], x3[i], color = "lightblue")
    plt.scatter(time[i], y3[i], color = "blue")


#IF I WANT THE PLOT OF THE ORBITS
'''
plt.plot(x1, y1, label='1', color = 'red')
plt.plot(x2, y2, label='2', color = 'green')
plt.plot(x3, y3, label='3', color = 'blue')
'''
plt.title('three masses simulation...')
plt.xlabel('x')
plt.ylabel('y')
#plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True)
#plt.legend()
plt.show()

# %% [markdown]
# ## plotting the velocity

# %%
plt.figure(figsize=(10, 8))
#IF I WANT POINTS:

for i in range(len(vx_1)):
    plt.scatter(vx_1[i], vy_1[i])
for i in range(len(vx_2)):
    plt.scatter(vx_2[i], vy_2[i])
for i in range(len(vx_3)):
    plt.scatter(vx_3[i], vy_3[i])


#IF I WANT THE PLOT OF THE ORBITS
plt.plot(vx_1, vy_1, label='1', color = 'red')
plt.plot(vx_2, vy_2, label='2', color = 'green')
plt.plot(vx_3, vy_3, label='3', color = 'blue')

plt.title('three masses simulation...')
plt.xlabel('vx')
plt.ylabel('vy')
#plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True)
plt.legend()
plt.show()

# %%
#if i wanted to do it with arrays... 
#timelapse = np.array(["n_bodies","time"])

#for i in range(n_bodies):
    #timelapse.append("1", f"x {i+1}: ",f"y{i+1}",f"z{i+1}", f"vx{i+1}",f"vy{i+1}",f"vz{i+1}")
    #timelapse = np.append(timelapse, ["1", f"x {i+1}: ",f"y{i+1}",f"z{i+1}", f"vx{i+1}",f"vy{i+1}",f"vz{i+1}"] )
#print (timelapse.shape)


    #timelapse = np.append(([timelapse], array), axis = 0)

# %%
print(f.read())
# Out:
# 3
# 1.009683292521411
# 1 0.9897069007297181 0.2235109578712773 0 -0.4136156720190455 0.4440307140425451 0
# 1 -0.04171517829958487 0.03859082267230612 0 0.9356534105818086 -0.8605658873713762 0
# 1 -0.9479917224301343 -0.2621017805435834 0 -0.5220377385627627 0.4165351733288307 0
# 3
# 2.008239195321538
# 1 0.09432319302353478 0.08623646241095788 0 -0.9484356787916073 -0.8436987631465583 0
# 1 0.9168292881794237 -0.2846041586507996 0 0.5960666879337866 0.3896065273172001 0
# 1 -1.011152481202958 0.1983676962398417 0 0.3523689908578202 0.454092235829358 0
# 3
# 3.010893884291143
# 1 -0.8839891670686627 -0.3041589003768859 0 -0.668487672247644 0.3554655261070158 0
# 1 1.028028981888268 0.1747764000472914 0 -0.2999246742563293 0.4600658499601383 0
# 1 -0.1440398148196055 0.1293825003295941 0 0.9684123465039747 -0.8155313760671551 0
# 3
# 4.004827298533358
# 1 -1.044419774070486 0.1465453168593974 0 0.2432194507804202 0.4642444103080985 0
# 1 0.203520227853479 0.1774125349295068 0 -0.9989666413471703 -0.7669407525831609 0
# 1 0.840899546217009 -0.323957851788905 0 0.7557471905667515 0.3026963422750618 0
# 3
# 5.002611420800955
# 1 -0.2609376332069616 0.2189713616297131 0 1.03168680681919 -0.7045610075598689 0
# 1 -0.7957970921222539 -0.3393625246457355 0 -0.8374934669914934 0.2383958765987803 0
# 1 1.056734725329219 0.1203911630160213 0 -0.1941933398276939 0.4661651309610882 0
# 3
# 6.003795548036492
# 1 0.7493147827417624 -0.3501694690994556 0 0.9109711338247056 0.1635530276488059 0
# 1 -1.065941552509556 0.09557135907098234 0 0.1508520161589804 0.4670168972208359 0
# 1 0.316626769767801 0.2545981100284712 0 -1.061823149983685 -0.6305699248696434 0
# 3
# 7.007632362621681
# 1 1.072624947464457 0.07188201107877507 0 -0.1117408231561016 0.4672736650326152 0
# 1 -0.3710912179581811 0.2845247456112176 0 1.086323731968015 -0.5465877865711332 0
# 1 -0.7015337295062675 -0.3564067566899971 0 -0.9745829088119143 0.07931412153851522 0
# 3
# 8.003580944555706
# 1 0.4352826278427979 0.3133260674114481 0 -1.104381109690884 -0.4353964104596859 0
# 1 0.6425999667636089 -0.3577696070107784 0 1.036036879271257 -0.03186882474055717 0
# 1 -1.077882594606399 0.04444353959932257 0 0.06834423041962712 0.46726523520024 0
# 3
# 9.001046528138071
# 1 -0.5821954606677395 -0.3526857147835861 0 -1.078961035699673 -0.1508447821202573 0
# 1 1.080551068485663 0.01797007834860021 0 -0.02735408198685729 0.4672200028674242 0
# 1 -0.4983556078179154 0.3347156364349753 0 1.10631511768653 -0.3163752207471707 0
# 3
# 10.00847699916697
# 1 -1.081032480785939 -0.004140733582969548 0 -0.006202387783966288 0.4672051847281543 0
# 1 0.549974215203295 0.3472594781271789 0 -1.093805635087632 -0.2148946220062611 0
# 1 0.53105826558265 -0.343118744544224 0 1.100008022871598 -0.2523105627218965 0
